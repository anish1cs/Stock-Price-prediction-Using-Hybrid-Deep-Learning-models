# %%
# ARIMA-CNN-LSTM Hybrid Model for Stock Index Prediction

# 📦 Import Required Libraries
#import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.arima.model import ARIMA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Bidirectional, Dropout, Dense
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Out:
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data = pd.read_csv("goog_2025.csv")
close_prices = data['Close'].dropna()

# %%
# 🔁 Fit ARIMA Model
arima_model = ARIMA(close_prices, order=(5, 1, 4))
arima_result = arima_model.fit()
residuals = arima_result.resid
# Out:
# U:\Projects_Umesh\Ann\venv\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
scaler = MinMaxScaler()
scaled_residuals = scaler.fit_transform(residuals.values.reshape(-1, 1))

# %%
# 🔄 Create Sequences for CNN-LSTM Input
def create_sequences(data, window_size=60):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i - window_size:i])
        y.append(data[i])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_residuals)
X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
# 🧠 Build CNN-LSTM Model
model = Sequential([
    Conv1D(32, kernel_size=3, activation='relu', input_shape=(X.shape[1], 1)),
    MaxPooling1D(pool_size=2),
    Conv1D(64, kernel_size=5, activation='relu'),
    MaxPooling1D(pool_size=2),
    Conv1D(128, kernel_size=5, activation='relu'),
    MaxPooling1D(pool_size=2),
    Bidirectional(LSTM(50)),
    Dropout(0.2),
    Dense(1)
])
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(X, y, epochs=10, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 47/47 [==============================] - 18s 109ms/step - loss: 0.0033 - val_loss: 0.0045
# Epoch 2/10
# 47/47 [==============================] - 2s 38ms/step - loss: 8.9982e-04 - val_loss: 0.0044
# Epoch 3/10
# 47/47 [==============================] - 2s 37ms/step - loss: 8.4655e-04 - val_loss: 0.0044
# Epoch 4/10
# 47/47 [==============================] - 2s 40ms/step - loss: 8.7175e-04 - val_loss: 0.0045
# Epoch 5/10
# 47/47 [==============================] - 2s 41ms/step - loss: 8.7679e-04 - val_loss: 0.0043
# Epoch 6/10
# 47/47 [==============================] - 2s 42ms/step - loss: 8.5849e-04 - val_loss: 0.0043
# Epoch 7/10
# 47/47 [==============================] - 1s 30ms/step - loss: 8.3826e-04 - val_loss: 0.0044
# Epoch 8/10
# 47/47 [==============================] - 2s 38ms/step - loss: 8.4563e-04 - val_loss: 0.0043
# Epoch 9/10
# 47/47 [==============================] - 2s 40ms/step - loss: 8.1099e-04 - val_loss: 0.0043
# Epoch 10/10
# 47/47 [==============================] - 2s 34ms/step - loss: 8.1628e-04 - val_loss: 0.0043

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training History')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# ✅ Predict and Invert Scaling (Optional)
y_pred = model.predict(X)
y_pred_inverted = scaler.inverse_transform(y_pred)
y_true_inverted = scaler.inverse_transform(y)
# Out:
# 59/59 [==============================] - 3s 9ms/step

# %%
plt.figure(figsize=(12, 5))
plt.plot(y_true_inverted, label='Actual')
plt.plot(y_pred_inverted, label='Predicted')
plt.title('Stock Index Prediction - ARIMA-CNN-LSTM')
plt.xlabel('Time Steps')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# 📊 Evaluation Metrics
mse = mean_squared_error(y_true_inverted, y_pred_inverted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true_inverted, y_pred_inverted)

print("Evaluation Metrics:")
print(f"MSE: {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# Evaluation Metrics:
# MSE: 1.7088
# RMSE: 1.3072
# MAE: 0.8258

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.arima.model import ARIMA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dropout, Dense, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Out:
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
try:
    data = pd.read_csv("goog_2025.csv")
except FileNotFoundError:
    print("Error: 'goog_2025.csv' not found. Please ensure the file is in the correct directory.")
    # Create a dummy dataframe to prevent script from crashing
    data = pd.DataFrame({'Close': np.random.rand(1000) * 100 + 100})

close_prices = data['Close'].dropna()

# %%
print("Fitting ARIMA model...")
arima_model = ARIMA(close_prices, order=(5, 1, 4))
arima_result = arima_model.fit()
residuals = arima_result.resid
print("ARIMA fitting complete.")
# Out:
# Fitting ARIMA model...
# ARIMA fitting complete.
# U:\Projects_Umesh\Ann\venv\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Scale the residuals (non-linear component)
scaler = MinMaxScaler()
scaled_residuals = scaler.fit_transform(residuals.values.reshape(-1, 1))

# Create Sequences for the deep learning model input
def create_sequences(data, window_size=60):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i - window_size:i])
        y.append(data[i])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_residuals)
X = X.reshape((X.shape[0], X.shape[1], 1))
# --- 2. Build a Regularized CNN-LSTM Model ---
# This model is simpler and includes several anti-overfitting techniques

# Clear any previous models from memory
from tensorflow.keras import backend as K
K.clear_session()

model = Sequential([
    # Reduced the number of filters and added L2 regularization
    Conv1D(
        filters=32,
        kernel_size=5,
        activation='relu',
        input_shape=(X.shape[1], 1),
        kernel_regularizer=l2(0.001) # L2 Regularization
    ),
    MaxPooling1D(pool_size=2),

    # A single, powerful Bidirectional LSTM layer is often sufficient
    # Added L2 regularization and recurrent_dropout
    Bidirectional(LSTM(
        50,
        activation='tanh', # Tanh is the default and often works well for LSTMs
        kernel_regularizer=l2(0.001), # L2 Regularization on input weights
        recurrent_dropout=0.2 # Dropout on recurrent connections
    )),

    # Increased the dropout rate for stronger regularization
    Dropout(0.4),

    # Final output layer
    Dense(1)
])

# Use a custom optimizer with a slightly lower learning rate
optimizer = Adam(learning_rate=0.0005)

model.compile(optimizer=optimizer, loss='mean_squared_error')

model.summary()
# Out:
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 56, 32)            192
#
#  max_pooling1d (MaxPooling1  (None, 28, 32)            0
#  D)
#
#  bidirectional (Bidirection  (None, 100)               33200
#  al)
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 33493 (130.83 KB)
# Trainable params: 33493 (130.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# --- 3. Train the Model with Early Stopping ---

# EarlyStopping callback will monitor 'val_loss' and stop training
# when it has not improved for 'patience' epochs.
# 'restore_best_weights=True' ensures the model weights are from the best epoch.
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10, # Number of epochs with no improvement after which training will be stopped.
    verbose=1,
    restore_best_weights=True
)

# Train the model for more epochs, letting Early Stopping find the optimal number
print("\nTraining model with Early Stopping...")
history = model.fit(
    X,
    y,
    epochs=100, # Train for more epochs; early stopping will halt it at the right time
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stopping], # Add the callback here
    verbose=1
)
print("Model training complete.")
# Out:
# Training model with Early Stopping...
# Epoch 1/100
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 47/47 [==============================] - 21s 125ms/step - loss: 0.0993 - val_loss: 0.0782
# Epoch 2/100
# 47/47 [==============================] - 4s 80ms/step - loss: 0.0619 - val_loss: 0.0527
# Epoch 3/100
# 47/47 [==============================] - 4s 79ms/step - loss: 0.0407 - val_loss: 0.0358
# Epoch 4/100
# 47/47 [==============================] - 4s 83ms/step - loss: 0.0268 - val_loss: 0.0248
# Epoch 5/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.0179 - val_loss: 0.0178
# Epoch 6/100
# 47/47 [==============================] - 4s 83ms/step - loss: 0.0122 - val_loss: 0.0133
# Epoch 7/100
# 47/47 [==============================] - 4s 82ms/step - loss: 0.0086 - val_loss: 0.0105
# Epoch 8/100
# 47/47 [==============================] - 4s 76ms/step - loss: 0.0063 - val_loss: 0.0087
# Epoch 9/100
# 47/47 [==============================] - 4s 79ms/step - loss: 0.0049 - val_loss: 0.0076
# Epoch 10/100
# 47/47 [==============================] - 4s 76ms/step - loss: 0.0039 - val_loss: 0.0069
# Epoch 11/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 12/100
# 47/47 [==============================] - 4s 79ms/step - loss: 0.0028 - val_loss: 0.0060
# Epoch 13/100
# 47/47 [==============================] - 4s 76ms/step - loss: 0.0025 - val_loss: 0.0057
# Epoch 14/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.0023 - val_loss: 0.0055
# Epoch 15/100
# 47/47 [==============================] - 4s 78ms/step - loss: 0.0021 - val_loss: 0.0053
# Epoch 16/100
# 47/47 [==============================] - 4s 78ms/step - loss: 0.0019 - val_loss: 0.0052
# Epoch 17/100
# 47/47 [==============================] - 4s 80ms/step - loss: 0.0017 - val_loss: 0.0051
# Epoch 18/100
# 47/47 [==============================] - 4s 79ms/step - loss: 0.0017 - val_loss: 0.0050
# Epoch 19/100
# 47/47 [==============================] - 4s 86ms/step - loss: 0.0016 - val_loss: 0.0049
# Epoch 20/100
# 47/47 [==============================] - 4s 93ms/step - loss: 0.0015 - val_loss: 0.0048
# Epoch 21/100
# 47/47 [==============================] - 4s 85ms/step - loss: 0.0014 - val_loss: 0.0047
# Epoch 22/100
# 47/47 [==============================] - 4s 86ms/step - loss: 0.0013 - val_loss: 0.0047
# Epoch 23/100
# 47/47 [==============================] - 4s 84ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 24/100
# 47/47 [==============================] - 4s 78ms/step - loss: 0.0012 - val_loss: 0.0046
# Epoch 25/100
# 47/47 [==============================] - 4s 76ms/step - loss: 0.0012 - val_loss: 0.0046
# Epoch 26/100
# 47/47 [==============================] - 4s 84ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 27/100
# 47/47 [==============================] - 4s 86ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 28/100
# 47/47 [==============================] - 4s 81ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 29/100
# 47/47 [==============================] - 4s 77ms/step - loss: 0.0010 - val_loss: 0.0044
# Epoch 30/100
# 47/47 [==============================] - 3s 64ms/step - loss: 9.9274e-04 - val_loss: 0.0044
# Epoch 31/100
# 47/47 [==============================] - 3s 73ms/step - loss: 9.6892e-04 - val_loss: 0.0044
# Epoch 32/100
# 47/47 [==============================] - 3s 71ms/step - loss: 9.7986e-04 - val_loss: 0.0045
# Epoch 33/100
# 47/47 [==============================] - 3s 71ms/step - loss: 9.5166e-04 - val_loss: 0.0044
# Epoch 34/100
# 47/47 [==============================] - 3s 73ms/step - loss: 9.0448e-04 - val_loss: 0.0044
# Epoch 35/100
# 47/47 [==============================] - 4s 76ms/step - loss: 9.0549e-04 - val_loss: 0.0044
# Epoch 36/100
# 47/47 [==============================] - 3s 75ms/step - loss: 8.9843e-04 - val_loss: 0.0043
# Epoch 37/100
# 47/47 [==============================] - 4s 77ms/step - loss: 8.7378e-04 - val_loss: 0.0043
# Epoch 38/100
# 47/47 [==============================] - 3s 70ms/step - loss: 8.7019e-04 - val_loss: 0.0044
# Epoch 39/100
# 47/47 [==============================] - 3s 66ms/step - loss: 8.8210e-04 - val_loss: 0.0043
# Epoch 40/100
# 47/47 [==============================] - 3s 74ms/step - loss: 8.6810e-04 - val_loss: 0.0044
# Epoch 41/100
# 47/47 [==============================] - 4s 77ms/step - loss: 8.3221e-04 - val_loss: 0.0044
# Epoch 42/100
# 47/47 [==============================] - 3s 74ms/step - loss: 8.5528e-04 - val_loss: 0.0043
# Epoch 43/100
# 47/47 [==============================] - 4s 76ms/step - loss: 8.1230e-04 - val_loss: 0.0043
# Epoch 44/100
# 47/47 [==============================] - 4s 77ms/step - loss: 8.3012e-04 - val_loss: 0.0043
# Epoch 45/100
# 47/47 [==============================] - 4s 77ms/step - loss: 8.2660e-04 - val_loss: 0.0043
# Epoch 46/100
# 47/47 [==============================] - 4s 76ms/step - loss: 8.0682e-04 - val_loss: 0.0043
# Epoch 47/100
# 47/47 [==============================] - 3s 72ms/step - loss: 7.9942e-04 - val_loss: 0.0043
# Epoch 48/100
# 47/47 [==============================] - 4s 78ms/step - loss: 7.9628e-04 - val_loss: 0.0043
# Epoch 49/100
# 47/47 [==============================] - 4s 82ms/step - loss: 8.0469e-04 - val_loss: 0.0043
# Epoch 50/100
# 47/47 [==============================] - 4s 78ms/step - loss: 7.8312e-04 - val_loss: 0.0043
# Epoch 51/100
# 47/47 [==============================] - 3s 74ms/step - loss: 7.7945e-04 - val_loss: 0.0043
# Epoch 52/100
# 47/47 [==============================] - 3s 70ms/step - loss: 7.8165e-04 - val_loss: 0.0043
# Epoch 53/100
# 47/47 [==============================] - 3s 70ms/step - loss: 7.5952e-04 - val_loss: 0.0043
# Epoch 54/100
# 47/47 [==============================] - 3s 72ms/step - loss: 7.9971e-04 - val_loss: 0.0043
# Epoch 55/100
# 47/47 [==============================] - 3s 72ms/step - loss: 7.6267e-04 - val_loss: 0.0043
# Epoch 56/100
# 47/47 [==============================] - 3s 74ms/step - loss: 7.5845e-04 - val_loss: 0.0043
# Epoch 57/100
# 47/47 [==============================] - 3s 68ms/step - loss: 7.5817e-04 - val_loss: 0.0043
# Epoch 58/100
# 47/47 [==============================] - 3s 65ms/step - loss: 7.5913e-04 - val_loss: 0.0043
# Epoch 59/100
# 47/47 [==============================] - 4s 76ms/step - loss: 7.5934e-04 - val_loss: 0.0043
# Epoch 60/100
# 47/47 [==============================] - 4s 76ms/step - loss: 7.4856e-04 - val_loss: 0.0043
# Epoch 61/100
# 47/47 [==============================] - 3s 71ms/step - loss: 7.3953e-04 - val_loss: 0.0043
# Epoch 62/100
# 47/47 [==============================] - 4s 76ms/step - loss: 7.2728e-04 - val_loss: 0.0043
# Epoch 63/100
# 47/47 [==============================] - 4s 76ms/step - loss: 7.4700e-04 - val_loss: 0.0043
# Epoch 64/100
# 47/47 [==============================] - 4s 77ms/step - loss: 7.4097e-04 - val_loss: 0.0043
# Epoch 65/100
# 47/47 [==============================] - 3s 72ms/step - loss: 7.3020e-04 - val_loss: 0.0043
# Epoch 66/100
# 47/47 [==============================] - 3s 70ms/step - loss: 7.5985e-04 - val_loss: 0.0043
# Epoch 67/100
# 47/47 [==============================] - 4s 76ms/step - loss: 7.4992e-04 - val_loss: 0.0043
# Epoch 68/100
# 47/47 [==============================] - 4s 85ms/step - loss: 7.4320e-04 - val_loss: 0.0043
# Epoch 69/100
# 47/47 [==============================] - 4s 83ms/step - loss: 7.5756e-04 - val_loss: 0.0043
# Epoch 70/100
# 47/47 [==============================] - 4s 83ms/step - loss: 7.4818e-04 - val_loss: 0.0043
# Epoch 71/100
# 47/47 [==============================] - 4s 77ms/step - loss: 7.2633e-04 - val_loss: 0.0043
# Epoch 72/100
# 47/47 [==============================] - 4s 79ms/step - loss: 7.3068e-04 - val_loss: 0.0043
# Epoch 73/100
# 47/47 [==============================] - 4s 87ms/step - loss: 7.2031e-04 - val_loss: 0.0043
# Epoch 74/100
# 47/47 [==============================] - 4s 83ms/step - loss: 7.2774e-04 - val_loss: 0.0043
# Epoch 75/100
# 47/47 [==============================] - 4s 87ms/step - loss: 7.3419e-04 - val_loss: 0.0043
# Epoch 76/100
# 47/47 [==============================] - 4s 86ms/step - loss: 7.2572e-04 - val_loss: 0.0043
# Epoch 77/100
# 47/47 [==============================] - 4s 82ms/step - loss: 7.2144e-04 - val_loss: 0.0043
# Epoch 78/100
# 47/47 [==============================] - 4s 82ms/step - loss: 7.3144e-04 - val_loss: 0.0043
# Epoch 79/100
# 47/47 [==============================] - 4s 86ms/step - loss: 7.3146e-04 - val_loss: 0.0043
# Epoch 80/100
# 47/47 [==============================] - 4s 85ms/step - loss: 7.2218e-04 - val_loss: 0.0043
# Epoch 81/100
# 47/47 [==============================] - 4s 87ms/step - loss: 7.2090e-04 - val_loss: 0.0043
# Epoch 82/100
# 47/47 [==============================] - 4s 84ms/step - loss: 7.1023e-04 - val_loss: 0.0043
# Epoch 83/100
# 47/47 [==============================] - 4s 87ms/step - loss: 7.3568e-04 - val_loss: 0.0043
# Epoch 84/100
# 47/47 [==============================] - 4s 90ms/step - loss: 7.1730e-04 - val_loss: 0.0043
# Epoch 85/100
# 47/47 [==============================] - 4s 87ms/step - loss: 7.0970e-04 - val_loss: 0.0043
# Epoch 86/100
# 47/47 [==============================] - ETA: 0s - loss: 7.1903e-04Restoring model weights from the end of the best epoch: 76.
# 47/47 [==============================] - 4s 81ms/step - loss: 7.1903e-04 - val_loss: 0.0043
# Epoch 86: early stopping
# Model training complete.

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_pred = model.predict(X)
y_pred_inverted = scaler.inverse_transform(y_pred)
y_true_inverted = scaler.inverse_transform(y)
# Out:
# 59/59 [==============================] - 2s 14ms/step

# %%
plt.figure(figsize=(14, 7))
plt.plot(y_true_inverted, label='Actual Residuals', color='blue', alpha=0.7)
plt.plot(y_pred_inverted, label='Predicted Residuals', color='red', linestyle='--', alpha=0.8)
plt.title('Residuals Prediction - Regularized ARIMA-CNN-LSTM')
plt.xlabel('Time Steps')
plt.ylabel('Residual Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
mse = mean_squared_error(y_true_inverted, y_pred_inverted)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_true_inverted, y_pred_inverted)

print("\n--- Evaluation Metrics ---")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
# Out:
# --- Evaluation Metrics ---
# Mean Squared Error (MSE): 1.6812
# Root Mean Squared Error (RMSE): 1.2966
# Mean Absolute Error (MAE): 0.7989

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dropout, Dense, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

# %%
try:
    data = pd.read_csv("goog_2025.csv")
except FileNotFoundError:
    print("Error: 'goog_2025.csv' not found. Please ensure the file is in the correct directory.")
    # Create a dummy dataframe to prevent script from crashing
    data = pd.DataFrame({'Close': np.random.rand(1000) * 100 + 100})

close_prices = data['Close'].dropna()

# %%
# --- 2. Fit ARIMA model for trend ---
print("Fitting ARIMA model...")
arima_model = ARIMA(close_prices, order=(5, 1, 4))
arima_result = arima_model.fit()
print("ARIMA fitting complete.")
# Out:
# Fitting ARIMA model...
# ARIMA fitting complete.
# U:\Projects_Umesh\Ann\venv\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# --- 3. Prepare residuals for deep learning ---
residuals = arima_result.resid
scaler = MinMaxScaler()
scaled_residuals = scaler.fit_transform(residuals.values.reshape(-1, 1))

def create_sequences(data, window_size=60):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i - window_size:i])
        y.append(data[i])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_residuals)
X = X.reshape((X.shape[0], X.shape[1], 1))

# %%
# --- 4. Build CNN-LSTM Model ---
K.clear_session()
model = Sequential([
    Conv1D(32, kernel_size=5, activation='relu', input_shape=(X.shape[1], 1), kernel_regularizer=l2(0.001)),
    MaxPooling1D(pool_size=2),
    Bidirectional(LSTM(50, activation='tanh', kernel_regularizer=l2(0.001), recurrent_dropout=0.2)),
    Dropout(0.4),
    Dense(1)
])
model.compile(optimizer=Adam(learning_rate=0.0005), loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 56, 32)            192
#
#  max_pooling1d (MaxPooling1  (None, 28, 32)            0
#  D)
#
#  bidirectional (Bidirection  (None, 100)               33200
#  al)
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 33493 (130.83 KB)
# Trainable params: 33493 (130.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# --- 5. Train Model with EarlyStopping ---
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
print("\nTraining model...")
history = model.fit(X, y, epochs=100, batch_size=32, validation_split=0.2, callbacks=[early_stopping], verbose=1)
print("Training complete.")
# Out:
# Training model...
# Epoch 1/100
# 47/47 [==============================] - 14s 110ms/step - loss: 0.0994 - val_loss: 0.0798
# Epoch 2/100
# 47/47 [==============================] - 5s 106ms/step - loss: 0.0634 - val_loss: 0.0541
# Epoch 3/100
# 47/47 [==============================] - 5s 112ms/step - loss: 0.0421 - val_loss: 0.0372
# Epoch 4/100
# 47/47 [==============================] - 6s 125ms/step - loss: 0.0281 - val_loss: 0.0259
# Epoch 5/100
# 47/47 [==============================] - 6s 118ms/step - loss: 0.0189 - val_loss: 0.0187
# Epoch 6/100
# 47/47 [==============================] - 5s 109ms/step - loss: 0.0131 - val_loss: 0.0141
# Epoch 7/100
# 47/47 [==============================] - 4s 85ms/step - loss: 0.0093 - val_loss: 0.0112
# Epoch 8/100
# 47/47 [==============================] - 3s 57ms/step - loss: 0.0069 - val_loss: 0.0093
# Epoch 9/100
# 47/47 [==============================] - 5s 106ms/step - loss: 0.0053 - val_loss: 0.0081
# Epoch 10/100
# 47/47 [==============================] - 5s 113ms/step - loss: 0.0043 - val_loss: 0.0073
# Epoch 11/100
# 47/47 [==============================] - 6s 124ms/step - loss: 0.0036 - val_loss: 0.0067
# Epoch 12/100
# 47/47 [==============================] - 5s 112ms/step - loss: 0.0031 - val_loss: 0.0063
# Epoch 13/100
# 47/47 [==============================] - 6s 124ms/step - loss: 0.0028 - val_loss: 0.0059
# Epoch 14/100
# 47/47 [==============================] - 6s 123ms/step - loss: 0.0025 - val_loss: 0.0057
# Epoch 15/100
# 47/47 [==============================] - 5s 107ms/step - loss: 0.0022 - val_loss: 0.0055
# Epoch 16/100
# 47/47 [==============================] - 6s 122ms/step - loss: 0.0020 - val_loss: 0.0053
# Epoch 17/100
# 47/47 [==============================] - 6s 118ms/step - loss: 0.0019 - val_loss: 0.0051
# Epoch 18/100
# 47/47 [==============================] - 6s 135ms/step - loss: 0.0017 - val_loss: 0.0050
# Epoch 19/100
# 47/47 [==============================] - 6s 121ms/step - loss: 0.0016 - val_loss: 0.0049
# Epoch 20/100
# 47/47 [==============================] - 5s 106ms/step - loss: 0.0015 - val_loss: 0.0048
# Epoch 21/100
# 47/47 [==============================] - 6s 124ms/step - loss: 0.0014 - val_loss: 0.0048
# Epoch 22/100
# 47/47 [==============================] - 6s 130ms/step - loss: 0.0013 - val_loss: 0.0047
# Epoch 23/100
# 47/47 [==============================] - 4s 96ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 24/100
# 47/47 [==============================] - 4s 96ms/step - loss: 0.0012 - val_loss: 0.0046
# Epoch 25/100
# 47/47 [==============================] - 5s 101ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 26/100
# 47/47 [==============================] - 5s 111ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 27/100
# 47/47 [==============================] - 5s 118ms/step - loss: 0.0011 - val_loss: 0.0044
# Epoch 28/100
# 47/47 [==============================] - 6s 124ms/step - loss: 0.0010 - val_loss: 0.0044
# Epoch 29/100
# 47/47 [==============================] - 5s 107ms/step - loss: 9.9449e-04 - val_loss: 0.0045
# Epoch 30/100
# 47/47 [==============================] - 5s 106ms/step - loss: 9.7984e-04 - val_loss: 0.0044
# Epoch 31/100
# 47/47 [==============================] - 5s 107ms/step - loss: 9.1799e-04 - val_loss: 0.0044
# Epoch 32/100
# 47/47 [==============================] - 5s 116ms/step - loss: 9.5114e-04 - val_loss: 0.0043
# Epoch 33/100
# 47/47 [==============================] - 5s 102ms/step - loss: 8.8219e-04 - val_loss: 0.0044
# Epoch 34/100
# 47/47 [==============================] - 5s 113ms/step - loss: 8.4999e-04 - val_loss: 0.0043
# Epoch 35/100
# 47/47 [==============================] - 6s 119ms/step - loss: 8.8045e-04 - val_loss: 0.0043
# Epoch 36/100
# 47/47 [==============================] - 6s 127ms/step - loss: 8.6211e-04 - val_loss: 0.0043
# Epoch 37/100
# 47/47 [==============================] - 5s 107ms/step - loss: 8.3171e-04 - val_loss: 0.0043
# Epoch 38/100
# 47/47 [==============================] - 5s 116ms/step - loss: 8.4052e-04 - val_loss: 0.0043
# Epoch 39/100
# 47/47 [==============================] - 6s 122ms/step - loss: 8.3645e-04 - val_loss: 0.0043
# Epoch 40/100
# 47/47 [==============================] - 5s 108ms/step - loss: 8.1190e-04 - val_loss: 0.0043
# Epoch 41/100
# 47/47 [==============================] - 8s 176ms/step - loss: 7.9851e-04 - val_loss: 0.0043
# Epoch 42/100
# 47/47 [==============================] - 6s 119ms/step - loss: 8.1348e-04 - val_loss: 0.0043
# Epoch 43/100
# 47/47 [==============================] - 4s 97ms/step - loss: 7.9451e-04 - val_loss: 0.0043
# Epoch 44/100
# 47/47 [==============================] - 5s 99ms/step - loss: 8.1726e-04 - val_loss: 0.0043
# Epoch 45/100
# 47/47 [==============================] - 7s 149ms/step - loss: 7.8228e-04 - val_loss: 0.0043
# Epoch 46/100
# 47/47 [==============================] - 4s 89ms/step - loss: 7.7861e-04 - val_loss: 0.0043
# Epoch 47/100
# 47/47 [==============================] - 3s 59ms/step - loss: 7.7454e-04 - val_loss: 0.0043
# Epoch 48/100
# 47/47 [==============================] - 5s 102ms/step - loss: 7.7182e-04 - val_loss: 0.0043
# Epoch 49/100
# 47/47 [==============================] - 5s 102ms/step - loss: 7.6239e-04 - val_loss: 0.0043
# Epoch 50/100
# 47/47 [==============================] - 6s 134ms/step - loss: 7.6553e-04 - val_loss: 0.0043
# Epoch 51/100
# 47/47 [==============================] - 7s 144ms/step - loss: 7.7515e-04 - val_loss: 0.0043
# Epoch 52/100
# 47/47 [==============================] - 7s 138ms/step - loss: 7.3915e-04 - val_loss: 0.0043
# Epoch 53/100
# 47/47 [==============================] - 5s 115ms/step - loss: 7.4450e-04 - val_loss: 0.0043
# Epoch 54/100
# 47/47 [==============================] - 5s 110ms/step - loss: 7.6959e-04 - val_loss: 0.0043
# Epoch 55/100
# 47/47 [==============================] - 5s 105ms/step - loss: 7.5805e-04 - val_loss: 0.0043
# Epoch 56/100
# 47/47 [==============================] - 6s 126ms/step - loss: 7.6374e-04 - val_loss: 0.0043
# Epoch 57/100
# 47/47 [==============================] - 5s 108ms/step - loss: 7.6641e-04 - val_loss: 0.0043
# Epoch 58/100
# 47/47 [==============================] - 4s 93ms/step - loss: 7.5392e-04 - val_loss: 0.0043
# Epoch 59/100
# 47/47 [==============================] - 5s 102ms/step - loss: 7.4098e-04 - val_loss: 0.0043
# Epoch 60/100
# 47/47 [==============================] - 3s 54ms/step - loss: 7.3911e-04 - val_loss: 0.0043
# Epoch 61/100
# 47/47 [==============================] - 5s 106ms/step - loss: 7.2897e-04 - val_loss: 0.0043
# Epoch 62/100
# 47/47 [==============================] - 6s 136ms/step - loss: 7.1799e-04 - val_loss: 0.0043
# Epoch 63/100
# 47/47 [==============================] - 6s 131ms/step - loss: 7.4677e-04 - val_loss: 0.0043
# Epoch 64/100
# 47/47 [==============================] - 5s 100ms/step - loss: 7.2906e-04 - val_loss: 0.0043
# Epoch 65/100
# 47/47 [==============================] - 4s 94ms/step - loss: 7.4652e-04 - val_loss: 0.0043
# Epoch 66/100
# 47/47 [==============================] - 4s 94ms/step - loss: 7.5046e-04 - val_loss: 0.0043
# Epoch 67/100
# 47/47 [==============================] - 4s 92ms/step - loss: 7.3387e-04 - val_loss: 0.0043
# Epoch 68/100
# 47/47 [==============================] - 5s 99ms/step - loss: 7.2809e-04 - val_loss: 0.0043
# Epoch 69/100
# 47/47 [==============================] - 5s 99ms/step - loss: 7.1835e-04 - val_loss: 0.0043
# Epoch 70/100
# 47/47 [==============================] - 4s 96ms/step - loss: 7.2495e-04 - val_loss: 0.0043
# Epoch 71/100
# 47/47 [==============================] - 5s 99ms/step - loss: 7.2588e-04 - val_loss: 0.0043
# Epoch 72/100
# 47/47 [==============================] - 4s 94ms/step - loss: 7.3966e-04 - val_loss: 0.0043
# Epoch 73/100
# 47/47 [==============================] - 5s 97ms/step - loss: 7.2378e-04 - val_loss: 0.0043
# Epoch 74/100
# 47/47 [==============================] - 5s 96ms/step - loss: 7.3497e-04 - val_loss: 0.0043
# Epoch 75/100
# 47/47 [==============================] - 4s 93ms/step - loss: 7.1985e-04 - val_loss: 0.0043
# Epoch 76/100
# 47/47 [==============================] - 4s 96ms/step - loss: 7.0808e-04 - val_loss: 0.0043
# Epoch 77/100
# 47/47 [==============================] - 5s 100ms/step - loss: 7.1960e-04 - val_loss: 0.0043
# Epoch 78/100
# 47/47 [==============================] - 5s 104ms/step - loss: 7.1271e-04 - val_loss: 0.0043
# Epoch 79/100
# 47/47 [==============================] - 5s 104ms/step - loss: 7.1745e-04 - val_loss: 0.0043
# Epoch 80/100
# 47/47 [==============================] - 4s 94ms/step - loss: 7.1108e-04 - val_loss: 0.0043
# Epoch 81/100
# 47/47 [==============================] - 5s 98ms/step - loss: 7.1812e-04 - val_loss: 0.0043
# Epoch 82/100
# 47/47 [==============================] - 4s 92ms/step - loss: 7.1881e-04 - val_loss: 0.0043
# Epoch 83/100
# 47/47 [==============================] - 5s 98ms/step - loss: 7.0867e-04 - val_loss: 0.0043
# Epoch 84/100
# 47/47 [==============================] - 5s 98ms/step - loss: 7.1795e-04 - val_loss: 0.0043
# Epoch 85/100
# 47/47 [==============================] - 4s 96ms/step - loss: 7.1257e-04 - val_loss: 0.0043
# Epoch 86/100
# 46/47 [============================>.] - ETA: 0s - loss: 7.3651e-04Restoring model weights from the end of the best epoch: 76.
# 47/47 [==============================] - 5s 98ms/step - loss: 7.3490e-04 - val_loss: 0.0043
# Epoch 86: early stopping
# Training complete.

# %%
# --- 6. Plot Training Loss ---
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# --- 7. Predict Residuals and Reconstruct Prices ---
y_pred = model.predict(X)
y_pred_inverted = scaler.inverse_transform(y_pred)
y_true_inverted = scaler.inverse_transform(y)

# %%
# Combine ARIMA fitted values with predicted residuals to reconstruct prices
arima_fitted = arima_result.fittedvalues[-len(y_pred_inverted):]
predicted_prices = arima_fitted + y_pred_inverted.flatten()
true_prices = close_prices[-len(y_pred_inverted):].values
plot_dates = close_prices.index[-len(y_pred_inverted):]

# --- 8. Plot Final Results ---
plt.figure(figsize=(14, 7))
plt.plot(close_prices.index, close_prices.values, label='Actual Stock Price', color='blue', linewidth=1.5)
plt.plot(plot_dates, predicted_prices, label='Model Predicted Price', color='orange', linestyle='--', linewidth=2)
# Yearly ticks on X-axis
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gcf().autofmt_xdate()

plt.title('Google Stock Price Prediction (ARIMA + CNN-LSTM)', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Stock Price (USD)', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
# --- 9. Evaluation Metrics ---
mse = mean_squared_error(true_prices, predicted_prices)
rmse = np.sqrt(mse)
mae = mean_absolute_error(true_prices, predicted_prices)

print("\n--- Evaluation Metrics ---")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dropout, Dense, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

# --- 1. Load Data ---
try:
    data = pd.read_csv("goog_2025.csv")
except FileNotFoundError:
    print("Error: 'goog_2025.csv' not found. Please ensure the file is in the correct directory.")
    # Create a dummy dataframe to prevent script from crashing
    data = pd.DataFrame({'Close': np.random.rand(1000) * 100 + 100})

close_prices = data['Close'].dropna()

# --- 2. Fit ARIMA model for trend ---
print("Fitting ARIMA model...")
arima_model = ARIMA(close_prices, order=(5, 1, 4))
arima_result = arima_model.fit()
print("ARIMA fitting complete.")

# --- 3. Prepare residuals for deep learning ---
residuals = arima_result.resid
scaler = MinMaxScaler()
scaled_residuals = scaler.fit_transform(residuals.values.reshape(-1, 1))

def create_sequences(data, window_size=60):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i - window_size:i])
        y.append(data[i])
    return np.array(X), np.array(y)

X, y = create_sequences(scaled_residuals)
X = X.reshape((X.shape[0], X.shape[1], 1))

# --- 4. Build CNN-LSTM Model ---
K.clear_session()
model = Sequential([
    Conv1D(32, kernel_size=5, activation='relu', input_shape=(X.shape[1], 1), kernel_regularizer=l2(0.001)),
    MaxPooling1D(pool_size=2),
    Bidirectional(LSTM(50, activation='tanh', kernel_regularizer=l2(0.001), recurrent_dropout=0.2)),
    Dropout(0.4),
    Dense(1)
])
model.compile(optimizer=Adam(learning_rate=0.0005), loss='mean_squared_error')
model.summary()

# --- 5. Train Model with EarlyStopping ---
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
print("\nTraining model...")
history = model.fit(X, y, epochs=100, batch_size=32, validation_split=0.2, callbacks=[early_stopping], verbose=1)
print("Training complete.")

# --- 6. Plot Training Loss ---
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# --- 7. Predict Residuals and Reconstruct Prices ---
y_pred = model.predict(X)
y_pred_inverted = scaler.inverse_transform(y_pred)
y_true_inverted = scaler.inverse_transform(y)

# Combine ARIMA fitted values with predicted residuals to reconstruct prices
arima_fitted = arima_result.fittedvalues[-len(y_pred_inverted):]
predicted_prices = arima_fitted + y_pred_inverted.flatten()
true_prices = close_prices[-len(y_pred_inverted):].values
plot_dates = close_prices.index[-len(y_pred_inverted):]

# --- 8. Plot Final Results ---
plt.figure(figsize=(14, 7))
plt.plot(close_prices.index, close_prices.values, label='Actual Stock Price', color='blue', linewidth=1.5)
plt.plot(plot_dates, predicted_prices, label='Model Predicted Price', color='orange', linestyle='--', linewidth=2)

# Yearly ticks on X-axis
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gcf().autofmt_xdate()

plt.title('Google Stock Price Prediction (ARIMA + CNN-LSTM)', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Stock Price (USD)', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# --- 9. Evaluation Metrics ---
mse = mean_squared_error(true_prices, predicted_prices)
rmse = np.sqrt(mse)
mae = mean_absolute_error(true_prices, predicted_prices)

print("\n--- Evaluation Metrics ---")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
# Out:
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Fitting ARIMA model...
# U:\Projects_Umesh\Ann\venv\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA fitting complete.
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 56, 32)            192
#
#  max_pooling1d (MaxPooling1  (None, 28, 32)            0
#  D)
#
#  bidirectional (Bidirection  (None, 100)               33200
#  al)
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 33493 (130.83 KB)
# Trainable params: 33493 (130.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Training model...
# Epoch 1/100
# WARNING:tensorflow:From U:\Projects_Umesh\Ann\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 47/47 [==============================] - 61s 246ms/step - loss: 0.0982 - val_loss: 0.0799
# Epoch 2/100
# 47/47 [==============================] - 6s 135ms/step - loss: 0.0630 - val_loss: 0.0535
# Epoch 3/100
# 47/47 [==============================] - 7s 151ms/step - loss: 0.0413 - val_loss: 0.0362
# Epoch 4/100
# 47/47 [==============================] - 7s 153ms/step - loss: 0.0271 - val_loss: 0.0249
# Epoch 5/100
# 47/47 [==============================] - 7s 147ms/step - loss: 0.0178 - val_loss: 0.0176
# Epoch 6/100
# 47/47 [==============================] - 7s 150ms/step - loss: 0.0119 - val_loss: 0.0129
# Epoch 7/100
# 47/47 [==============================] - 7s 148ms/step - loss: 0.0081 - val_loss: 0.0100
# Epoch 8/100
# 47/47 [==============================] - 6s 134ms/step - loss: 0.0058 - val_loss: 0.0082
# Epoch 9/100
# 47/47 [==============================] - 7s 145ms/step - loss: 0.0042 - val_loss: 0.0070
# Epoch 10/100
# 47/47 [==============================] - 7s 140ms/step - loss: 0.0033 - val_loss: 0.0063
# Epoch 11/100
# 47/47 [==============================] - 7s 153ms/step - loss: 0.0027 - val_loss: 0.0058
# Epoch 12/100
# 47/47 [==============================] - 7s 152ms/step - loss: 0.0023 - val_loss: 0.0054
# Epoch 13/100
# 47/47 [==============================] - 7s 146ms/step - loss: 0.0019 - val_loss: 0.0052
# Epoch 14/100
# 47/47 [==============================] - 7s 146ms/step - loss: 0.0018 - val_loss: 0.0050
# Epoch 15/100
# 47/47 [==============================] - 8s 163ms/step - loss: 0.0015 - val_loss: 0.0049
# Epoch 16/100
# 47/47 [==============================] - 8s 172ms/step - loss: 0.0015 - val_loss: 0.0048
# Epoch 17/100
# 47/47 [==============================] - 8s 172ms/step - loss: 0.0014 - val_loss: 0.0047
# Epoch 18/100
# 47/47 [==============================] - 7s 159ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 19/100
# 47/47 [==============================] - 8s 164ms/step - loss: 0.0012 - val_loss: 0.0045
# Epoch 20/100
# 47/47 [==============================] - 7s 152ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 21/100
# 47/47 [==============================] - 8s 163ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 22/100
# 47/47 [==============================] - 8s 165ms/step - loss: 0.0011 - val_loss: 0.0044
# Epoch 23/100
# 47/47 [==============================] - 8s 161ms/step - loss: 9.9665e-04 - val_loss: 0.0044
# Epoch 24/100
# 47/47 [==============================] - 8s 163ms/step - loss: 9.8514e-04 - val_loss: 0.0044
# Epoch 25/100
# 47/47 [==============================] - 7s 157ms/step - loss: 9.2650e-04 - val_loss: 0.0044
# Epoch 26/100
# 47/47 [==============================] - 8s 167ms/step - loss: 9.5000e-04 - val_loss: 0.0044
# Epoch 27/100
# 47/47 [==============================] - 7s 155ms/step - loss: 9.4876e-04 - val_loss: 0.0044
# Epoch 28/100
# 47/47 [==============================] - 8s 161ms/step - loss: 8.8586e-04 - val_loss: 0.0043
# Epoch 29/100
# 47/47 [==============================] - 7s 160ms/step - loss: 9.4385e-04 - val_loss: 0.0043
# Epoch 30/100
# 47/47 [==============================] - 8s 165ms/step - loss: 8.8914e-04 - val_loss: 0.0043
# Epoch 31/100
# 47/47 [==============================] - 8s 159ms/step - loss: 8.6885e-04 - val_loss: 0.0043
# Epoch 32/100
# 47/47 [==============================] - 7s 153ms/step - loss: 8.6998e-04 - val_loss: 0.0043
# Epoch 33/100
# 47/47 [==============================] - 7s 153ms/step - loss: 8.4851e-04 - val_loss: 0.0043
# Epoch 34/100
# 47/47 [==============================] - 8s 163ms/step - loss: 8.3264e-04 - val_loss: 0.0043
# Epoch 35/100
# 47/47 [==============================] - 8s 160ms/step - loss: 8.1706e-04 - val_loss: 0.0043
# Epoch 36/100
# 47/47 [==============================] - 8s 161ms/step - loss: 8.3784e-04 - val_loss: 0.0043
# Epoch 37/100
# 47/47 [==============================] - 8s 181ms/step - loss: 7.7332e-04 - val_loss: 0.0043
# Epoch 46/100
# 47/47 [==============================] - 11s 233ms/step - loss: 7.7987e-04 - val_loss: 0.0043
# Epoch 47/100
# 47/47 [==============================] - 11s 229ms/step - loss: 7.7230e-04 - val_loss: 0.0043
# Epoch 48/100
# 47/47 [==============================] - 10s 214ms/step - loss: 7.6612e-04 - val_loss: 0.0043
# Epoch 49/100
# 47/47 [==============================] - 11s 227ms/step - loss: 7.5888e-04 - val_loss: 0.0043
# Epoch 50/100
# 47/47 [==============================] - 10s 220ms/step - loss: 7.7098e-04 - val_loss: 0.0043
# Epoch 51/100
# 47/47 [==============================] - 10s 217ms/step - loss: 7.4023e-04 - val_loss: 0.0043
# Epoch 52/100
# 47/47 [==============================] - 11s 230ms/step - loss: 7.7266e-04 - val_loss: 0.0043
# Epoch 53/100
# 47/47 [==============================] - 10s 217ms/step - loss: 7.3661e-04 - val_loss: 0.0043
# Epoch 54/100
# 47/47 [==============================] - 10s 210ms/step - loss: 7.2890e-04 - val_loss: 0.0043
# Epoch 55/100
# 47/47 [==============================] - 9s 196ms/step - loss: 7.4443e-04 - val_loss: 0.0043
# Epoch 56/100
# 47/47 [==============================] - 10s 213ms/step - loss: 7.4267e-04 - val_loss: 0.0043
# Epoch 57/100
# 47/47 [==============================] - 10s 218ms/step - loss: 7.4046e-04 - val_loss: 0.0043
# Epoch 58/100
# 47/47 [==============================] - 9s 196ms/step - loss: 7.3925e-04 - val_loss: 0.0043
# Epoch 59/100
# 47/47 [==============================] - 7s 149ms/step - loss: 7.3561e-04 - val_loss: 0.0043
# Epoch 60/100
# 47/47 [==============================] - 8s 167ms/step - loss: 7.3575e-04 - val_loss: 0.0043
# Epoch 61/100
# 47/47 [==============================] - 7s 159ms/step - loss: 7.2540e-04 - val_loss: 0.0043
# Epoch 62/100
# 47/47 [==============================] - 7s 155ms/step - loss: 7.3382e-04 - val_loss: 0.0043
# Epoch 63/100
# 47/47 [==============================] - 7s 149ms/step - loss: 7.1352e-04 - val_loss: 0.0043
# Epoch 64/100
# 47/47 [==============================] - 7s 148ms/step - loss: 7.4287e-04 - val_loss: 0.0043
# Epoch 65/100
# 47/47 [==============================] - 7s 145ms/step - loss: 7.3072e-04 - val_loss: 0.0043
# Epoch 66/100
# 47/47 [==============================] - 7s 147ms/step - loss: 7.2606e-04 - val_loss: 0.0043
# Epoch 67/100
# 47/47 [==============================] - 7s 154ms/step - loss: 7.2277e-04 - val_loss: 0.0043
# Epoch 68/100
# 47/47 [==============================] - 7s 156ms/step - loss: 7.1684e-04 - val_loss: 0.0043
# Epoch 69/100
# 47/47 [==============================] - 7s 154ms/step - loss: 7.3830e-04 - val_loss: 0.0043
# Epoch 70/100
# 47/47 [==============================] - 7s 153ms/step - loss: 7.1287e-04 - val_loss: 0.0043
# Epoch 71/100
# 47/47 [==============================] - 7s 151ms/step - loss: 7.2580e-04 - val_loss: 0.0043
# Epoch 72/100
# 47/47 [==============================] - 7s 142ms/step - loss: 7.1886e-04 - val_loss: 0.0043
# Epoch 73/100
# 47/47 [==============================] - 7s 146ms/step - loss: 7.2337e-04 - val_loss: 0.0043
# Epoch 74/100
# 47/47 [==============================] - 7s 147ms/step - loss: 7.3586e-04 - val_loss: 0.0043
# Epoch 75/100
# 47/47 [==============================] - 6s 137ms/step - loss: 7.0954e-04 - val_loss: 0.0043
# Epoch 76/100
# 47/47 [==============================] - 6s 136ms/step - loss: 7.0775e-04 - val_loss: 0.0043
# Epoch 77/100
# 47/47 [==============================] - 6s 130ms/step - loss: 7.1523e-04 - val_loss: 0.0043
# Epoch 78/100
# 47/47 [==============================] - 6s 131ms/step - loss: 7.1105e-04 - val_loss: 0.0043
# Epoch 79/100
# 47/47 [==============================] - 6s 127ms/step - loss: 7.1115e-04 - val_loss: 0.0043
# Epoch 80/100
# 47/47 [==============================] - 6s 131ms/step - loss: 7.1020e-04 - val_loss: 0.0043
# Epoch 81/100
# 47/47 [==============================] - 6s 128ms/step - loss: 7.1331e-04 - val_loss: 0.0043
# Epoch 82/100
# 47/47 [==============================] - 6s 129ms/step - loss: 7.1134e-04 - val_loss: 0.0043
# Epoch 83/100
# 47/47 [==============================] - ETA: 0s - loss: 7.1271e-04Restoring model weights from the end of the best epoch: 73.
# 47/47 [==============================] - 6s 134ms/step - loss: 7.1271e-04 - val_loss: 0.0043
# Epoch 83: early stopping
# Training complete.
# 59/59 [==============================] - 7s 31ms/step
# --- Evaluation Metrics ---
# Mean Squared Error (MSE): 1.6815
# Root Mean Squared Error (RMSE): 1.2967
# Mean Absolute Error (MAE): 0.7990

# %%
# --- 8. Plot Final Results ---
plt.figure(figsize=(14, 7))
plt.plot(close_prices.index, close_prices.values, label='Actual Stock Price', color='blue', linewidth=1.5)
plt.plot(plot_dates, predicted_prices, label='Model Predicted Price', color='orange', linestyle='--', linewidth=2)
# Yearly ticks on X-axis
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.gcf().autofmt_xdate()

plt.title('Google Stock Price Prediction (ARIMA + CNN-LSTM)', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Stock Price (USD)', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
